# %% [markdown]
# ### Importing  module

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, accuracy_score
import joblib

# %%
list(df)

# %%
inputs = ['Year',
 'Engine_Size',
 'Mileage',
 'Doors',
 'Owner_Count',
 'Brand_Audi',
 'Brand_BMW',
 'Brand_Chevrolet',
 'Brand_Ford',
 'Brand_Honda',
 'Brand_Hyundai',
 'Brand_Kia',
 'Brand_Mercedes',
 'Brand_Toyota',
 'Brand_Volkswagen',
 'Model_3 Series',
 'Model_5 Series',
 'Model_A3',
 'Model_A4',
 'Model_Accord',
 'Model_C-Class',
 'Model_CR-V',
 'Model_Camry',
 'Model_Civic',
 'Model_Corolla',
 'Model_E-Class',
 'Model_Elantra',
 'Model_Equinox',
 'Model_Explorer',
 'Model_Fiesta',
 'Model_Focus',
 'Model_GLA',
 'Model_Golf',
 'Model_Impala',
 'Model_Malibu',
 'Model_Optima',
 'Model_Passat',
 'Model_Q5',
 'Model_RAV4',
 'Model_Rio',
 'Model_Sonata',
 'Model_Sportage',
 'Model_Tiguan',
 'Model_Tucson',
 'Model_X5',
 'Transmission_Automatic',
 'Transmission_Manual',
 'Transmission_Semi-Automatic',
 'Fuel_Type_Diesel',
 'Fuel_Type_Electric',
 'Fuel_Type_Hybrid',
 'Fuel_Type_Petrol']
output = 'Price'

# %%
joblib.dump(lm, 'model.pkl')
# Out:
# ['model.pkl']

# %%
x_train, x_test, y_train, y_test = train_test_split(df[inputs], df[output], train_size=0.85, random_state=23)

# %%
lm = Ridge()
lm.fit(x_train, y_train)
# Out:
# Ridge()

# %%
y_pred = lm.predict(x_test)

# %%
y_pred
# Out:
# array([ 3819.80146817,  6394.90345638,  3860.26298059, ...,
#        12000.62667415,  5812.28368541,  8243.89828912], shape=(1500,))

# %%
y_test
# Out:
# 6326     3777
# 5185     6375
# 2495     3827
# 2765     8553
# 9303    13038
#         ...
# 2621     8153
# 2648     9721
# 5397    12026
# 8577     5791
# 7220     8224
# Name: Price, Length: 1500, dtype: int64

# %%
r2_score(y_pred=y_pred, y_true=y_test)*100
# Out:
# 99.97762707131565

# %%
accuracy_score(y_pred=y_pred, y_true=y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 accuracy_score(y_pred=y_pred, y_true=y_test)
#
# File g:\Data Science\Kawser\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
# ...

# %%
df = pd.read_csv("car_price_dataset.csv")
# df2 = pd.read_excel("car_data.xlsx")

# %%
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df = pd.get_dummies(df, columns=['Brand', 'Model','Transmission', 'Fuel_Type' ])

# %%
df.dtypes
# Out:
# Year                             int64
# Engine_Size                    float64
# Mileage                          int64
# Doors                            int64
# Owner_Count                      int64
# Price                            int64
# Brand_Audi                        bool
# Brand_BMW                         bool
# Brand_Chevrolet                   bool
# Brand_Ford                        bool
# Brand_Honda                       bool
# Brand_Hyundai                     bool
# Brand_Kia                         bool
# Brand_Mercedes                    bool
# Brand_Toyota                      bool
# Brand_Volkswagen                  bool
# Model_3 Series                    bool
# Model_5 Series                    bool
# Model_A3                          bool
# Model_A4                          bool
# Model_Accord                      bool
# Model_C-Class                     bool
# Model_CR-V                        bool
# Model_Camry                       bool
# ...

# %%
df.head(12)

# %%
df.iloc[90:100:2]

# %%
df.columns

# %%
df.dtypes

# %%
# missing values
df['Brand'].value_counts()

# %%
df['Price'].describe()

# %%
df.info()

# %%
df['Doors'].value_counts()

# %%
df[df['Brand']=='Ford']['Price'].describe()

# %%
df.dtypes

# %%
df[df['Year']>2012]

# %%
df.isnull().count()

# %%
df['Price'].

# %%
df.columns

# %%
df.rename(columns={
    'Year':"month",
})

# %%
df.to_excel('car_data.xlsx', index=False)

# %%
import random
def getSomeNone():
    for i in range(len(df)):
        if i % 3==0:
            return random.randint(0,101)
        else:
            return None

# %%
df['arst'].apply(getSomeNone())

# %%
df

# %% [markdown]
# ## MODEL

# %% [markdown]
# 1. train, test dataset
# 2. model fit
# 3. predict
# 4. accuracy
